# %%
import tensorflow as tf

# %%
import pandas as pd

# %%
TRAIN = "voice.csv"
TEST = "voice_test.csv"

# %%
df = pd.read_csv(TRAIN)

# %%
df = df.sample(frac=1).reset_index(drop=True)
df.head()
# Out:
#    meanfreq        sd    median       Q25       Q75       IQR      skew  \
# 0  0.194007  0.056983  0.211034  0.140690  0.239080  0.098391  0.988364
# 1  0.204982  0.061316  0.234010  0.133237  0.254976  0.121739  1.850012
# 2  0.168346  0.074121  0.145618  0.115756  0.239824  0.124068  2.704335
# 3  0.202284  0.061547  0.231223  0.135904  0.250213  0.114309  1.764681
# 4  0.223748  0.039713  0.223462  0.201154  0.252692  0.051538  1.876540
#
#         kurt    sp.ent       sfm   ...    centroid   meanfun    minfun  \
# 0   3.435651  0.918227  0.353041   ...    0.194007  0.123836  0.047013
# 1   5.706426  0.867338  0.283762   ...    0.204982  0.120147  0.018161
# 2  18.484703  0.934523  0.559742   ...    0.168346  0.083484  0.015717
# 3   6.101330  0.896098  0.356969   ...    0.202284  0.128484  0.046967
# 4   6.339011  0.852729  0.212552   ...    0.223748  0.174687  0.048096
#
#      maxfun   meandom    mindom    maxdom   dfrange   modindx   label
# ...

# %%
x_train, y_train = df.iloc[:, :-1].values, [1 if gender == "male" else 0 for gender in df.iloc[:,-1].values]
# x_train.columns

# %%
model = tf.keras.models.Sequential()
model.add(tf.keras.layers.Dense(units=5, activation='relu', input_dim=20))
model.add(tf.keras.layers.Dense(units=1, activation='sigmoid'))

# %%
# model.compile(loss=tf.keras.losses.binary_crossentropy,
#               optimizer=tf.keras.optimizers.SGD(lr=0.01, momentum=0.9, nesterov=True))
model.compile(optimizer='rmsprop',
              loss='binary_crossentropy',
              metrics=['accuracy']
             )

# %%
model.fit(x_train, y_train, epochs=2000, batch_size=64)
# Out:
# Epoch 1/2000
# 2393/2393 [==============================] - 0s - loss: 0.8735 - acc: 0.5232
# Epoch 2/2000
# 2393/2393 [==============================] - 0s - loss: 0.7644 - acc: 0.5453
# Epoch 3/2000
# 2393/2393 [==============================] - 0s - loss: 0.6959 - acc: 0.5641
# Epoch 4/2000
# 2393/2393 [==============================] - 0s - loss: 0.6669 - acc: 0.5625
# Epoch 5/2000
# 2393/2393 [==============================] - 0s - loss: 0.6605 - acc: 0.5867
# Epoch 6/2000
# 2393/2393 [==============================] - 0s - loss: 0.6544 - acc: 0.6076
# Epoch 7/2000
# 2393/2393 [==============================] - 0s - loss: 0.6516 - acc: 0.6114
# Epoch 8/2000
# 2393/2393 [==============================] - 0s - loss: 0.6469 - acc: 0.6306
# Epoch 9/2000
# 2393/2393 [==============================] - 0s - loss: 0.6439 - acc: 0.6364
# Epoch 10/2000
# 2393/2393 [==============================] - 0s - loss: 0.6387 - acc: 0.6527
# Epoch 11/2000
# ...

# %%
test_df = pd.read_csv(TEST)
test_df = test_df.sample(frac=1).reset_index(drop=True)
x_test, y_test = test_df.iloc[:, :-1].values, [1 if gender == "male" else 0 for gender in test_df.iloc[:,-1].values]

# %%
model.evaluate(x_test, y_test, batch_size=64)
# Out:
#  64/775 [=>............................] - ETA: 0s
# [0.12810404202630443, 0.96387096774193548]
